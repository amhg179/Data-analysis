# %% [markdown]
# Data ScienceTutorial for Beginners

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 1. INTRODUCTION TO PYTHON:

# %% [markdown]
# MATPLOTLIB

# %% [markdown]
# Matplot is a python library that help us to plot data. The easiest and most basic plots are line, scatter and histogram plots.
#
#
#
# 1.   Line plot is better when x axis is time.
# 2.   Scatter is better when there is correlation between two variables
# 3.  Histogram is better when we need to see distribution of numerical data.
# 4.   Customization: Colors,labels,thickness of line, title, opacity, grid, figsize, ticks of axis and linestyle

# %%
#line plot
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1,5)
y=2*x+1
z=x**2
plt.plot(x,y)
plt.title('relationship between x and y')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.plot(x,z)
plt.legend(['y=2x+1','z'],loc='upper right')
plt.grid()

# %%
# subplot
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)
z=np.cos(x)

# %%
fig,ax=plt.subplots()
ax.plot(x,y)
#title in sub plots
ax.set_title('sin(x2)')
# Out:
# Text(0.5, 1.0, 'sin(x2)')

# %%
#Vertically stacked subplots
fig,ax=plt.subplots(2)
ax[0].plot(x,y)
ax[1].plot(x,z)
fig.suptitle('Vertically stacked subplots')
# Out:
# Text(0.5, 0.98, 'Vertically stacked subplots')

# %%
#Horizontally stacked subplots
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')
ax1.plot(x, y)
ax2.plot(x, -y)

# %%
#multi subplots
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0, 0]')
axs[0, 1].plot(x, y, 'tab:orange')
axs[0, 1].set_title('Axis [0, 1]')
axs[1, 0].plot(x, -y, 'tab:green')
axs[1, 0].set_title('Axis [1, 0]')
axs[1, 1].plot(x, -y, 'tab:red')
axs[1, 1].set_title('Axis [1, 1]')

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# Scatter plots are used to observe relationship between variables and uses dots to represent the relationship between them. The scatter() method in the matplotlib library is used to draw a scatter plot. Scatter plots are widely used to represent relation among variables and how change in one affects the other.

# %% [markdown]
# The scatter() method takes in the following parameters:
#
# 1.  x_axis_data- An array containing x-axis data
# 2.  y_axis_data- An array containing y-axis data
# 3.  s- marker size (can be scalar or array of size equal to size of x or y)
# 4.  c- color of sequence of colors for markers
# 5.  marker- marker style
# 6.  cmap- cmap name
# 7.  linewidths- width of marker border
# 8.  edgecolor- marker border color
# 9.  alpha- blending value, between 0 (transparent) and 1 (opaque)

# %%
# scatter plot
x =[5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6] 
y =[99, 86, 87, 88, 100, 86, 103, 87, 94, 78, 77, 85, 86]
z=[89, 90, 70, 89, 100, 80, 90, 100, 80, 34,15,45,74]
plt.scatter(x, y, c ="blue", linewidths = 2,  marker ="s", edgecolor ="green", s = 50)
plt.scatter(x,z,c="red")

# %%
# histogram
x = np.random.normal(170, 10, 250)
plt.hist(x)
# Out:
# (array([ 1.,  3.,  8., 24., 42., 60., 45., 40., 23.,  4.]),
#  array([136.63210385, 142.52947397, 148.4268441 , 154.32421422,
#         160.22158434, 166.11895446, 172.01632459, 177.91369471,
#         183.81106483, 189.70843496, 195.60580508]),
#  <a list of 10 Patch objects>)

# %%
# !pip3 install pandas

# %%
#pandas
import pandas as pd
#data=pd.read_csv("train.csv")

# %%
data.to_string
# Out:
# <bound method DataFrame.to_string of       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  ...   MCV  AGE  SEX  SOURCE
# 0            35.1          11.8         4.65        6.3  ...  75.5    1    F     out
# 1            43.5          14.8         5.39       12.7  ...  80.7    1    F     out
# 2            33.5          11.3         4.74       13.2  ...  70.7    1    F     out
# 3            39.1          13.7         4.98       10.5  ...  78.5    1    F     out
# 4            30.9           9.9         4.23       22.1  ...  73.0    1    M     out
# ...           ...           ...          ...        ...  ...   ...  ...  ...     ...
# 3524         39.2          13.4         4.49       10.5  ...  87.3   67    F     out
# 3525         39.7          13.2         5.08       15.3  ...  78.1   67    F     out
# 3526         39.6          12.6         4.37        5.3  ...  90.6   67    M     out
# 3527         44.6          15.1         5.09        6.7  ...  87.6   67    M     out
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3529 entries, 0 to 3528
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HAEMATOCRIT   3529 non-null   float64
#  1   HAEMOGLOBINS  3529 non-null   float64
#  2   ERYTHROCYTE   3529 non-null   float64
#  3   LEUCOCYTE     3529 non-null   float64
#  4   THROMBOCYTE   3529 non-null   int64
#  5   MCH           3529 non-null   float64
#  6   MCHC          3529 non-null   float64
#  7   MCV           3529 non-null   float64
#  8   AGE           3529 non-null   int64
#  9   SEX           3529 non-null   object
#  10  SOURCE        3529 non-null   object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 303.4+ KB

# %%
x=data['HAEMATOCRIT']>55
data[x]
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  ...   MCV  AGE  SEX  SOURCE
# 1252         57.0          18.8         6.35        5.9  ...  89.8   32    M     out
# 1652         55.3          17.9         6.61       10.3  ...  83.7   38    M     out
# 3071         58.1          18.9         6.53       30.8  ...  89.0   61    M     out
# 3145         55.7          17.8         6.73       16.0  ...  82.8   62    M     out
# 3187         55.8          17.8         6.75       14.5  ...  82.7   62    M      in
# 3258         56.3          18.2         7.48        6.1  ...  75.3   63    M     out
#
# [6 rows x 11 columns]

# %%
data[np.logical_and(data['THROMBOCYTE']>200, data['MCH']>35 )]
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  ...    MCV  AGE  SEX  SOURCE
# 738          41.2          14.3         3.99        4.1  ...  103.3   24    M     out
# 1149         39.7          14.1         3.83        5.7  ...  103.7   30    M     out
# 2169         36.8          13.3         3.52        4.9  ...  104.5   47    M     out
#
# [3 rows x 11 columns]

# %%
data[(data['THROMBOCYTE']>200 )& (data['MCH']>35) ]
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  ...    MCV  AGE  SEX  SOURCE
# 738          41.2          14.3         3.99        4.1  ...  103.3   24    M     out
# 1149         39.7          14.1         3.83        5.7  ...  103.7   30    M     out
# 2169         36.8          13.3         3.52        4.9  ...  104.5   47    M     out
#
# [3 rows x 11 columns]

# %%
data=pd.read_csv("Book.csv")

# %%
null_data = data[data.isnull().any(axis=1)]
null_data
# Out:
#     HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  ...   MCV  AGE  SEX  SOURCE
# 10         33.7          11.5         4.57       13.2  ...  73.7  NaN    M     out
# 15         34.0          10.3         5.27       16.2  ...  64.5  1.0    M     out
# 18          NaN          10.8         4.02        7.9  ...  77.9  1.0    F     out
# 20         34.9          11.6          NaN        9.5  ...  74.1  1.0    F     out
# 22         33.7          11.0         4.69       18.4  ...  71.9  1.0    F     out
# 28         36.8          11.9         4.69        1.9  ...  78.5  1.0    F     NaN
#
# [6 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# HAEMATOCRIT     1
# HAEMOGLOBINS    0
# ERYTHROCYTE     1
# LEUCOCYTE       0
# THROMBOCYTE     0
# MCH             1
# MCHC            1
# MCV             0
# AGE             1
# SEX             0
# SOURCE          1
# dtype: int64

# %%
#remove rows had cells with empty values.
x=data.dropna(inplace = True)
print(data)
# Out:
#     HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  ...   MCV  AGE  SEX  SOURCE
# 0          35.1          11.8         4.65        6.3  ...  75.5  1.0    F     out
# 1          43.5          14.8         5.39       12.7  ...  80.7  1.0    F     out
# 2          33.5          11.3         4.74       13.2  ...  70.7  1.0    F     out
# 3          39.1          13.7         4.98       10.5  ...  78.5  1.0    F     out
# 4          30.9           9.9         4.23       22.1  ...  73.0  1.0    M     out
# 5          34.3          11.6         4.53        6.6  ...  75.7  1.0    M     out
# 6          31.1           8.7         5.06       11.1  ...  61.5  1.0    F     out
# 7          40.3          13.3         4.73        8.1  ...  85.2  1.0    F     out
# 8          33.6          11.5         4.54       11.4  ...  74.0  1.0    F     out
# 9          35.4          11.4         4.80        2.6  ...  73.8  1.0    F     out
# ...

# %%
#Replace NULL values with the number 130
data.fillna(130, inplace = True)
# Replace NULL values in selected column
#data['HAEMATOCRIT'].fillna(130, inplace = True)
data
# Out:
#     HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  ...   MCV    AGE  SEX  SOURCE
# 0          35.1          11.8         4.65        6.3  ...  75.5    1.0    F     out
# 1          43.5          14.8         5.39       12.7  ...  80.7    1.0    F     out
# 2          33.5          11.3         4.74       13.2  ...  70.7    1.0    F     out
# 3          39.1          13.7         4.98       10.5  ...  78.5    1.0    F     out
# 4          30.9           9.9         4.23       22.1  ...  73.0    1.0    M     out
# 5          34.3          11.6         4.53        6.6  ...  75.7    1.0    M     out
# 6          31.1           8.7         5.06       11.1  ...  61.5    1.0    F     out
# 7          40.3          13.3         4.73        8.1  ...  85.2    1.0    F     out
# 8          33.6          11.5         4.54       11.4  ...  74.0    1.0    F     out
# 9          35.4          11.4         4.80        2.6  ...  73.8    1.0    F     out
# ...

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3524    False
# 3525    False
# 3526    False
# 3527    False
# 3528    False
# Length: 3529, dtype: bool

# %%
data.plot()

# %%
# Stay in loop if condition( i is not equal 5) is true
lis = [1,2,3,4,5]
for i in lis:
    print('i is: ',i)
print('')

# Enumerate index and value of list
# index : value = 0:1, 1:2, 2:3, 3:4, 4:5
for index, value in enumerate(lis):
    print(index," : ",value)
print('')   

# For dictionaries
# We can use for loop to achive key and value of dictionary. We learnt key and value at dictionary part.
dictionary = {'spain':'madrid','france':'paris'}
for key,value in dictionary.items():
    print(key," : ",value)
print('')
# Out:
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5
#
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5
#
# spain  :  madrid
# france  :  paris

# %%
# For pandas we can achieve index and value
for index,value in data[['HAEMATOCRIT']][0:1].iterrows():
    print(index," : ",value)
# Out:
# 0  :  HAEMATOCRIT    35.1
# Name: 0, dtype: float64
